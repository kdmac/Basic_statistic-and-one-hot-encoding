# %% [markdown]
# ### This code is all about basic statistic and dealing with categorical variable

# %%
# Imporiting pandas library
import pandas as pd

# %%
# Reading data into pandas data frame
data = pd.read_csv(r'C:\KD_Doc\ML work\Lab_Home_work\exams.csv',quotechar='"')

# %%
# checking top rows of data
data.head(10)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0    male        group E          associate's degree      standard
# 1    male        group C          associate's degree      standard
# 2  female        group C                 high school      standard
# 3  female        group E           bachelor's degree  free/reduced
# 4  female        group C                some college      standard
# 5    male        group B                 high school      standard
# 6    male        group E                 high school      standard
# 7    male        group E                some college      standard
# 8    male        group B                some college      standard
# 9    male        group B                 high school  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0               completed         100             98            100
# 1                    none          70             77             73
# ...

# %%
print("Math Avg : ",data["math score"].mean())
print("reading Avg : ",data["reading score"].mean())
print("writing Avg : ",data["writing score"].mean())
# Out:
# Math Avg :  66.37
# reading Avg :  68.47
# writing Avg :  67.11

# %% [markdown]
# ### Standardization of data

# %%
# Standardization of data - Preprocessing step
from sklearn import preprocessing

# %%
data["math score"] = preprocessing.scale(data["math score"])
data["reading score"] = preprocessing.scale(data["reading score"])
data["writing score"] = preprocessing.scale(data["writing score"])

# %%
data.head(10)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0    male        group E          associate's degree      standard
# 1    male        group C          associate's degree      standard
# 2  female        group C                 high school      standard
# 3  female        group E           bachelor's degree  free/reduced
# 4  female        group C                some college      standard
# 5    male        group B                 high school      standard
# 6    male        group E                 high school      standard
# 7    male        group E                some college      standard
# 8    male        group B                some college      standard
# 9    male        group B                 high school  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0               completed    2.289647       2.103984       2.238618
# 1                    none    0.247143       0.607754       0.400896
# ...

# %% [markdown]
# ##### Checking data Standardization is done properly or not by checking mean value which should be near 0 of Standardization columns

# %%
print("Math Avg : ",data["math score"].mean())
print("reading Avg : ",data["reading score"].mean())
print("writing Avg : ",data["writing score"].mean())
# Out:
# Math Avg :  -3.252953462151709e-16
# reading Avg :  1.3211653993039362e-16
# writing Avg :  4.218847493575595e-17

# %% [markdown]
# ## Standardization of categorical columns
# ### one-hot encoding

# %%
# Instilization of LabelEncoder()
le = preprocessing.LabelEncoder()

# %%
data.dtypes
# Out:
# gender                          object
# race/ethnicity                  object
# parental level of education     object
# lunch                           object
# test preparation course         object
# math score                     float64
# reading score                  float64
# writing score                  float64
# dtype: object

# %%
data = pd.get_dummies(data,columns=["gender","race/ethnicity","parental level of education","lunch","test preparation course"],
                      drop_first=True)

# %%
data.head()
# Out:
#    math score  reading score  writing score  gender_male  \
# 0    2.289647       2.103984       2.238618            1
# 1    0.247143       0.607754       0.400896            1
# 2   -0.161358       0.322758       0.196704            0
# 3   -0.025191       0.465256       0.128641            0
# 4   -0.433692      -0.389732      -0.279742            0
#
#    race/ethnicity_group B  race/ethnicity_group C  race/ethnicity_group D  \
# 0                       0                       0                       0
# 1                       0                       1                       0
# 2                       0                       1                       0
# 3                       0                       0                       0
# 4                       0                       1                       0
#
#    race/ethnicity_group E  parental level of education_bachelor's degree  \
# 0                       1                                              0
# ...

# %% [markdown]
# ## Code understanding
# ##### pd.get_dummies allows one-hot encoding of multipule columns in one go.
# ##### drop_frist = True will consider frist lable as reference leble and delete that column.
